# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from tensorflow.keras.models import load_model
from PIL import Image

def load_trained_model(model_path):
    """Load the trained model from a file."""
    return load_model(model_path)

def preprocess_image(image_path, target_size):
    """Preprocess the input image before passing it to the model."""
    # Load image and convert to RGB
    image = np.array(Image.open(image_path).convert("RGB"))
    # Resize the image
    image = resize_image(image, target_size)
    # Normalize the image (same as the training preprocessing)
    image = image.astype(np.float32) / 255.0  # Normalizing to [0, 1]
    # Add batch dimension
    image = np.expand_dims(image, axis=0)
    return image

def predict_mask(model, image_path, target_size):
    """Predict the segmentation mask for a given image."""
    # Preprocess the image
    image = preprocess_image(image_path, target_size)

    # Perform inference
    prediction = model.predict(image)

    # Get the predicted mask (argmax across channels to select the class with the highest probability)
    predicted_mask = np.argmax(prediction, axis=-1)
    # Remove batch dimension and expand to match mask shape
    predicted_mask = np.squeeze(predicted_mask, axis=0)

    return predicted_mask

def display_mask(predicted_mask, target_size):
    """Display the predicted mask using PIL."""
    # Convert the mask to an image
    mask_image = Image.fromarray(predicted_mask.astype(np.uint8))
    mask_image = mask_image.resize(target_size, Image.Resampling.LANCZOS)
    mask_image.show()

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

def visualize_image_and_mask(image_path, predicted_mask, target_size):
    """Visualize the original image and its predicted mask side by side."""
    # Load the original image
    original_image = Image.open(image_path).convert("RGB")
    original_image = original_image.resize(target_size, Image.Resampling.LANCZOS)

    # Convert predicted mask to an image for visualization
    mask_image = Image.fromarray(predicted_mask.astype(np.uint8))
    mask_image = mask_image.resize(target_size, Image.Resampling.LANCZOS)

    # Create a side-by-side plot
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(original_image)
    axes[0].set_title("Original Image")
    axes[0].axis('off')  # Hide axes

    axes[1].imshow(mask_image, cmap='jet')  # Use a color map for better visualization of the mask
    axes[1].set_title("Predicted Mask")
    axes[1].axis('off')  # Hide axes

    plt.tight_layout()
    plt.show()

# %%
import os
import numpy as np
from tensorflow.keras.utils import Sequence
import tensorflow as tf
from tensorflow.keras import mixed_precision
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split
from PIL import Image
from tensorflow.keras.saving import register_keras_serializable
from tensorflow.keras.models import load_model

# Enable mixed precision training
mixed_precision.set_global_policy('mixed_float16')

def resize_image(image, target_size):
    """Resize the image to the target size using PIL."""
    return np.array(Image.fromarray(image).resize(target_size, Image.Resampling.LANCZOS))

class DataGenerator(Sequence):
    def __init__(self, image_files, mask_files, batch_size, image_folder, mask_folder, patch_size, num_classes=8, augment=False):
        self.image_files = image_files
        self.mask_files = mask_files
        self.batch_size = batch_size
        self.image_folder = image_folder
        self.mask_folder = mask_folder
        self.patch_size = patch_size
        self.num_classes = num_classes
        self.augment = augment
        self.on_epoch_end()

    def __len__(self):
        return len(self.image_files) // self.batch_size

    def __getitem__(self, index):
        batch_images = self.image_files[index * self.batch_size:(index + 1) * self.batch_size]
        batch_masks = self.mask_files[index * self.batch_size:(index + 1) * self.batch_size]

        images, masks = [], []
        for img_file, mask_file in zip(batch_images, batch_masks):
            image = np.array(Image.open(os.path.join(self.image_folder, img_file)).convert("RGB"))
            image = resize_image(image, (self.patch_size, self.patch_size))

            mask = np.array(Image.open(os.path.join(self.mask_folder, mask_file)).convert("L"))
            mask = resize_image(mask, (self.patch_size, self.patch_size))
            mask = one_hot_encode_mask(mask, num_classes=self.num_classes)

            images.append(image)
            masks.append(mask)

        images = np.array(images).astype(np.float32)
        masks = np.array(masks).astype(np.float32)

        return images, masks

    def on_epoch_end(self):
        combined = list(zip(self.image_files, self.mask_files))
        np.random.shuffle(combined)
        self.image_files, self.mask_files = zip(*combined)

def one_hot_encode_mask(mask, num_classes):
    """Convert a grayscale mask to a one-hot encoded format."""
    one_hot = np.zeros((mask.shape[0], mask.shape[1], num_classes), dtype=np.float32)
    for c in range(num_classes):
        one_hot[:, :, c] = (mask == c).astype(np.float32)
    return one_hot

def decoder_block(input_tensor, skip_features, num_filters):
    x = layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input_tensor)
    x = layers.Concatenate()([x, skip_features])
    x = layers.Conv2D(num_filters, (3, 3), activation="relu", padding="same")(x)
    x = layers.Conv2D(num_filters, (3, 3), activation="relu", padding="same")(x)
    return x

def build_unet_vgg16(input_shape, num_classes):
    vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
    for layer in vgg16.layers:
        layer.trainable = False  # Freeze layers initially

    s1 = vgg16.get_layer('block1_conv2').output
    s2 = vgg16.get_layer('block2_conv2').output
    s3 = vgg16.get_layer('block3_conv3').output
    s4 = vgg16.get_layer('block4_conv3').output
    p4 = vgg16.get_layer('block5_conv3').output

    d1 = decoder_block(p4, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    d4 = layers.BatchNormalization()(d4)

    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax')(d4)
    return Model(inputs=vgg16.input, outputs=outputs)

@register_keras_serializable()
def dice_coefficient(y_true, y_pred, smooth=1e-5):
    y_pred = tf.cast(y_pred, tf.float32)  # Cast y_pred to float32
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

@register_keras_serializable()
def dice_loss(y_true, y_pred):
    smooth = 1e-5
    y_pred = tf.cast(y_pred, tf.float32)  # Cast y_pred to float32
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    return 1 - (2. * intersection + smooth) / (union + smooth)

# Paths
image_folder = '/content/drive/MyDrive/originals'
mask_folder = '/content/drive/MyDrive/masks'
patch_size = 128

image_files = sorted(os.listdir(image_folder))
mask_files = sorted(os.listdir(mask_folder))

train_images, val_images, train_masks, val_masks = train_test_split(image_files, mask_files, test_size=0.2, random_state=42)

batch_size = 4
train_generator = DataGenerator(train_images, train_masks, batch_size, image_folder, mask_folder, patch_size, augment=False)
val_generator = DataGenerator(val_images, val_masks, batch_size, image_folder, mask_folder, patch_size, augment=False)

input_shape = (patch_size, patch_size, 3)
num_classes = 8
model = build_unet_vgg16(input_shape, num_classes)

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=dice_loss,
    metrics=['accuracy', MeanIoU(num_classes=num_classes), dice_coefficient]
)

checkpoint = ModelCheckpoint('unet_model_best.keras', save_best_only=True, monitor='val_accuracy', mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

with tf.device('/GPU:0'):
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=1000,
        callbacks=[checkpoint, early_stopping, lr_scheduler]
    )

model.save('final_unet_model.keras')

val_loss, val_accuracy, val_mean_iou, val_dice = model.evaluate(val_generator)

print(f"Validation Loss: {val_loss * 100:.2f}%")
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
print(f"Validation Mean IoU: {val_mean_iou * 100:.2f}%")
print(f"Validation Dice Coefficient: {val_dice * 100:.2f}%")
# Out:
# Epoch 1/1000
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - accuracy: 0.2949 - dice_coefficient: 0.2629 - loss: 0.7371 - mean_io_u_1: 0.4376 - val_accuracy: 0.4504 - val_dice_coefficient: 0.4401 - val_loss: 0.5599 - val_mean_io_u_1: 0.5656 - learning_rate: 0.0010
# Epoch 2/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.4459 - dice_coefficient: 0.4328 - loss: 0.5672 - mean_io_u_1: 0.4453 - val_accuracy: 0.5071 - val_dice_coefficient: 0.5022 - val_loss: 0.4978 - val_mean_io_u_1: 0.6272 - learning_rate: 0.0010
# Epoch 3/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 882ms/step - accuracy: 0.4752 - dice_coefficient: 0.4619 - loss: 0.5381 - mean_io_u_1: 0.4554 - val_accuracy: 0.5389 - val_dice_coefficient: 0.5362 - val_loss: 0.4638 - val_mean_io_u_1: 0.6182 - learning_rate: 0.0010
# Epoch 4/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.4922 - dice_coefficient: 0.4828 - loss: 0.5172 - mean_io_u_1: 0.4598 - val_accuracy: 0.5088 - val_dice_coefficient: 0.5026 - val_loss: 0.4974 - val_mean_io_u_1: 0.5544 - learning_rate: 0.0010
# Epoch 5/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 543ms/step - accuracy: 0.5255 - dice_coefficient: 0.4993 - loss: 0.5007 - mean_io_u_1: 0.4621 - val_accuracy: 0.5517 - val_dice_coefficient: 0.5138 - val_loss: 0.4862 - val_mean_io_u_1: 0.4761 - learning_rate: 0.0010
# Epoch 6/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.6427 - dice_coefficient: 0.5845 - loss: 0.4155 - mean_io_u_1: 0.4508 - val_accuracy: 0.7205 - val_dice_coefficient: 0.6667 - val_loss: 0.3333 - val_mean_io_u_1: 0.4838 - learning_rate: 0.0010
# Epoch 7/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 273ms/step - accuracy: 0.7258 - dice_coefficient: 0.6703 - loss: 0.3297 - mean_io_u_1: 0.4524 - val_accuracy: 0.7170 - val_dice_coefficient: 0.6766 - val_loss: 0.3234 - val_mean_io_u_1: 0.4589 - learning_rate: 0.0010
# Epoch 8/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - accuracy: 0.7401 - dice_coefficient: 0.7064 - loss: 0.2936 - mean_io_u_1: 0.4452 - val_accuracy: 0.7362 - val_dice_coefficient: 0.7183 - val_loss: 0.2817 - val_mean_io_u_1: 0.4807 - learning_rate: 0.0010
# Epoch 9/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 361ms/step - accuracy: 0.7777 - dice_coefficient: 0.7516 - loss: 0.2484 - mean_io_u_1: 0.4523 - val_accuracy: 0.8527 - val_dice_coefficient: 0.8462 - val_loss: 0.1538 - val_mean_io_u_1: 0.7168 - learning_rate: 0.0010
# Epoch 10/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - accuracy: 0.8130 - dice_coefficient: 0.7928 - loss: 0.2072 - mean_io_u_1: 0.4655 - val_accuracy: 0.8038 - val_dice_coefficient: 0.7932 - val_loss: 0.2068 - val_mean_io_u_1: 0.4986 - learning_rate: 0.0010
# Epoch 11/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - accuracy: 0.8150 - dice_coefficient: 0.8000 - loss: 0.2000 - mean_io_u_1: 0.4678 - val_accuracy: 0.7980 - val_dice_coefficient: 0.7888 - val_loss: 0.2112 - val_mean_io_u_1: 0.4885 - learning_rate: 0.0010
# Epoch 12/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 320ms/step - accuracy: 0.8266 - dice_coefficient: 0.8154 - loss: 0.1846 - mean_io_u_1: 0.4703 - val_accuracy: 0.8199 - val_dice_coefficient: 0.7966 - val_loss: 0.2034 - val_mean_io_u_1: 0.4906 - learning_rate: 0.0010
# Epoch 13/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 370ms/step - accuracy: 0.8238 - dice_coefficient: 0.8065 - loss: 0.1935 - mean_io_u_1: 0.5230 - val_accuracy: 0.8576 - val_dice_coefficient: 0.8430 - val_loss: 0.1570 - val_mean_io_u_1: 0.4743 - learning_rate: 0.0010
# Epoch 14/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 222ms/step - accuracy: 0.8236 - dice_coefficient: 0.8055 - loss: 0.1945 - mean_io_u_1: 0.4909 - val_accuracy: 0.8440 - val_dice_coefficient: 0.8307 - val_loss: 0.1693 - val_mean_io_u_1: 0.4822 - learning_rate: 0.0010
# Epoch 15/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 352ms/step - accuracy: 0.8534 - dice_coefficient: 0.8453 - loss: 0.1547 - mean_io_u_1: 0.5142 - val_accuracy: 0.8981 - val_dice_coefficient: 0.8920 - val_loss: 0.1080 - val_mean_io_u_1: 0.5561 - learning_rate: 5.0000e-04
# Epoch 16/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.8629 - dice_coefficient: 0.8560 - loss: 0.1440 - mean_io_u_1: 0.5168 - val_accuracy: 0.8652 - val_dice_coefficient: 0.8598 - val_loss: 0.1402 - val_mean_io_u_1: 0.5214 - learning_rate: 5.0000e-04
# Epoch 17/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.8736 - dice_coefficient: 0.8654 - loss: 0.1346 - mean_io_u_1: 0.5274 - val_accuracy: 0.8443 - val_dice_coefficient: 0.8382 - val_loss: 0.1618 - val_mean_io_u_1: 0.4980 - learning_rate: 5.0000e-04
# Epoch 18/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.8869 - dice_coefficient: 0.8816 - loss: 0.1184 - mean_io_u_1: 0.5485 - val_accuracy: 0.8812 - val_dice_coefficient: 0.8742 - val_loss: 0.1258 - val_mean_io_u_1: 0.5123 - learning_rate: 5.0000e-04
# Epoch 19/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - accuracy: 0.8900 - dice_coefficient: 0.8840 - loss: 0.1160 - mean_io_u_1: 0.5414 - val_accuracy: 0.8665 - val_dice_coefficient: 0.8595 - val_loss: 0.1405 - val_mean_io_u_1: 0.5209 - learning_rate: 5.0000e-04
# Epoch 20/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - accuracy: 0.8866 - dice_coefficient: 0.8806 - loss: 0.1194 - mean_io_u_1: 0.5132 - val_accuracy: 0.8963 - val_dice_coefficient: 0.8909 - val_loss: 0.1091 - val_mean_io_u_1: 0.5231 - learning_rate: 5.0000e-04
# Epoch 21/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.8914 - dice_coefficient: 0.8857 - loss: 0.1143 - mean_io_u_1: 0.5794 - val_accuracy: 0.8601 - val_dice_coefficient: 0.8561 - val_loss: 0.1439 - val_mean_io_u_1: 0.5196 - learning_rate: 2.5000e-04
# Epoch 22/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - accuracy: 0.8946 - dice_coefficient: 0.8897 - loss: 0.1103 - mean_io_u_1: 0.6414 - val_accuracy: 0.8630 - val_dice_coefficient: 0.8578 - val_loss: 0.1422 - val_mean_io_u_1: 0.5140 - learning_rate: 2.5000e-04
# Epoch 23/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 189ms/step - accuracy: 0.8975 - dice_coefficient: 0.8924 - loss: 0.1076 - mean_io_u_1: 0.5916 - val_accuracy: 0.8548 - val_dice_coefficient: 0.8501 - val_loss: 0.1499 - val_mean_io_u_1: 0.5101 - learning_rate: 2.5000e-04
# Epoch 24/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - accuracy: 0.8919 - dice_coefficient: 0.8883 - loss: 0.1117 - mean_io_u_1: 0.5587 - val_accuracy: 0.8780 - val_dice_coefficient: 0.8735 - val_loss: 0.1265 - val_mean_io_u_1: 0.5100 - learning_rate: 2.5000e-04
# Epoch 25/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 298ms/step - accuracy: 0.8917 - dice_coefficient: 0.8877 - loss: 0.1123 - mean_io_u_1: 0.5939 - val_accuracy: 0.8536 - val_dice_coefficient: 0.8500 - val_loss: 0.1500 - val_mean_io_u_1: 0.5057 - learning_rate: 2.5000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.8941 - dice_coefficient: 0.8880 - loss: 0.1120 - mean_io_u_1: 0.5565
# Validation Loss: 10.80%
# Validation Accuracy: 89.81%
# Validation Mean IoU: 55.61%
# Validation Dice Coefficient: 89.20%

# %%
# Get the last epoch's training loss, accuracy, and dice coefficient
last_epoch_loss = history.history['loss'][-1]
last_epoch_accuracy = history.history['accuracy'][-1]
last_epoch_dice = history.history['dice_coefficient'][-1]

# Convert to percentage format
last_epoch_loss_percentage = last_epoch_loss * 100
last_epoch_accuracy_percentage = last_epoch_accuracy * 100
last_epoch_dice_percentage = last_epoch_dice * 100

# Print the results for the last epoch
print(f"Training Loss (last epoch): {last_epoch_loss_percentage:.2f}%")
print(f"Training Accuracy (last epoch): {last_epoch_accuracy_percentage:.2f}%")
print(f"Training Dice Coefficient (last epoch): {last_epoch_dice_percentage:.2f}%")

# If you want to get the mean of the training metrics over all epochs
mean_training_loss = np.mean(history.history['loss']) * 100
mean_training_accuracy = np.mean(history.history['accuracy']) * 100
mean_training_dice = np.mean(history.history['dice_coefficient']) * 100

# Print the mean values for training metrics
print(f"Mean Training Loss: {mean_training_loss:.2f}%")
print(f"Mean Training Accuracy: {mean_training_accuracy:.2f}%")
print(f"Mean Training Dice Coefficient: {mean_training_dice:.2f}%")

# Evaluate the model on the validation set to get validation metrics
val_loss, val_accuracy, val_mean_iou, val_dice = model.evaluate(val_generator)

# Convert validation metrics to percentages
val_loss_percentage = val_loss * 100
val_accuracy_percentage = val_accuracy * 100
val_mean_iou_percentage = val_mean_iou * 100
val_dice_percentage = val_dice * 100

# Print the validation results
print(f"Validation Loss: {val_loss_percentage:.2f}%")
print(f"Validation Accuracy: {val_accuracy_percentage:.2f}%")
print(f"Validation Mean IoU: {val_mean_iou_percentage:.2f}%")
print(f"Validation Dice Coefficient: {val_dice_percentage:.2f}%")

# Optionally, you can also print the mean of validation metrics if tracked during training
mean_val_loss = np.mean(history.history['val_loss']) * 100
mean_val_accuracy = np.mean(history.history['val_accuracy']) * 100
mean_val_dice = np.mean(history.history['val_dice_coefficient']) * 100  # Use correct key for validation Dice Coefficient

print(f"Mean Validation Loss: {mean_val_loss:.2f}%")
print(f"Mean Validation Accuracy: {mean_val_accuracy:.2f}%")
print(f"Mean Validation Dice Coefficient: {mean_val_dice:.2f}%")
# Out:
# Training Loss (last epoch): 10.73%
# Training Accuracy (last epoch): 89.65%
# Training Dice Coefficient (last epoch): 89.27%
# Mean Training Loss: 25.56%
# Mean Training Accuracy: 76.14%
# Mean Training Dice Coefficient: 74.44%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - accuracy: 0.8601 - dice_coefficient: 0.8548 - loss: 0.1452 - mean_io_u_1: 0.5522
# Validation Loss: 15.48%
# Validation Accuracy: 85.04%
# Validation Mean IoU: 54.64%
# Validation Dice Coefficient: 84.52%
# Mean Validation Loss: 24.17%
# Mean Validation Accuracy: 77.07%
# Mean Validation Dice Coefficient: 75.83%

# %%
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'dice_coefficient', 'loss', 'mean_io_u_1', 'val_accuracy', 'val_dice_coefficient', 'val_loss', 'val_mean_io_u_1', 'learning_rate'])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get the last epoch's training loss, accuracy, and dice coefficient
last_epoch_loss = history.history['loss'][-1]
last_epoch_accuracy = history.history['accuracy'][-1]
last_epoch_dice = history.history['dice_coefficient'][-1]

# Convert to percentage format
last_epoch_loss_percentage = last_epoch_loss * 100
last_epoch_accuracy_percentage = last_epoch_accuracy * 100
last_epoch_dice_percentage = last_epoch_dice * 100

# Print the results for the last epoch
print(f"Training Loss (last epoch): {last_epoch_loss_percentage:.2f}%")
print(f"Training Accuracy (last epoch): {last_epoch_accuracy_percentage:.2f}%")
print(f"Training Dice Coefficient (last epoch): {last_epoch_dice_percentage:.2f}%")

# If you want to get the mean of the training metrics over all epochs
mean_training_loss = np.mean(history.history['loss']) * 100
mean_training_accuracy = np.mean(history.history['accuracy']) * 100
mean_training_dice = np.mean(history.history['dice_coefficient']) * 100

# Print the mean values for training metrics
print(f"Mean Training Loss: {mean_training_loss:.2f}%")
print(f"Mean Training Accuracy: {mean_training_accuracy:.2f}%")
print(f"Mean Training Dice Coefficient: {mean_training_dice:.2f}%")

# Evaluate the model on the validation set to get validation metrics
val_loss, val_accuracy, val_mean_iou, val_dice = model.evaluate(val_generator)

# Convert validation metrics to percentages
val_loss_percentage = val_loss * 100
val_accuracy_percentage = val_accuracy * 100
val_mean_iou_percentage = val_mean_iou * 100
val_dice_percentage = val_dice * 100

# Print the validation results
print(f"Validation Loss: {val_loss_percentage:.2f}%")
print(f"Validation Accuracy: {val_accuracy_percentage:.2f}%")
print(f"Validation Mean IoU: {val_mean_iou_percentage:.2f}%")
print(f"Validation Dice Coefficient: {val_dice_percentage:.2f}%")

# Optionally, print the mean of validation metrics if tracked during training
mean_val_loss = np.mean(history.history['val_loss']) * 100
mean_val_accuracy = np.mean(history.history['val_accuracy']) * 100
mean_val_dice = np.mean(history.history['val_dice_coefficient']) * 100  # Use correct key for validation Dice Coefficient

print(f"Mean Validation Loss: {mean_val_loss:.2f}%")
print(f"Mean Validation Accuracy: {mean_val_accuracy:.2f}%")
print(f"Mean Validation Dice Coefficient: {mean_val_dice:.2f}%")

# Plot the metrics
fig, axes = plt.subplots(2, 3, figsize=(18, 12))

# Plot Training Loss
axes[0, 0].plot(history.history['loss'], label='Training Loss', color='blue')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss', color='red')
axes[0, 0].set_title('Training and Validation Loss')
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss (%)')
axes[0, 0].legend()

# Plot Training Accuracy
axes[0, 1].plot(history.history['accuracy'], label='Training Accuracy', color='blue')
axes[0, 1].plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
axes[0, 1].set_title('Training and Validation Accuracy')
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy (%)')
axes[0, 1].legend()

# Plot Training and Validation Dice Coefficient
axes[0, 2].plot(history.history['dice_coefficient'], label='Training Dice Coefficient', color='purple')
axes[0, 2].plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient', color='orange')
axes[0, 2].set_title('Training and Validation Dice Coefficient')
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Dice Coefficient (%)')
axes[0, 2].legend()

# Plot Validation Mean IoU
axes[1, 0].plot(history.history['mean_io_u_1'], label='Validation Mean IoU', color='green')
axes[1, 0].set_title('Validation Mean IoU')
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Mean IoU (%)')
axes[1, 0].legend()

# Plot all metrics (Accuracy, Loss, Mean IoU, Dice Coefficient)
axes[1, 1].plot(history.history['accuracy'], label='Training Accuracy', color='blue')
axes[1, 1].plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
axes[1, 1].plot(history.history['loss'], label='Training Loss', color='blue', linestyle='--')
axes[1, 1].plot(history.history['val_loss'], label='Validation Loss', color='red', linestyle='--')
axes[1, 1].plot(history.history['val_mean_io_u_1'], label='Validation Mean IoU', color='green', linestyle='-.')
axes[1, 1].plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient', color='orange', linestyle='-.')
axes[1, 1].set_title('All Metrics')
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Metric Value')
axes[1, 1].legend()

# Empty plot for aesthetics
axes[1, 2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Training Loss (last epoch): 10.73%
# Training Accuracy (last epoch): 89.65%
# Training Dice Coefficient (last epoch): 89.27%
# Mean Training Loss: 25.56%
# Mean Training Accuracy: 76.14%
# Mean Training Dice Coefficient: 74.44%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 436ms/step - accuracy: 0.8663 - dice_coefficient: 0.8612 - loss: 0.1388 - mean_io_u_1: 0.5534
# Validation Loss: 14.98%
# Validation Accuracy: 85.51%
# Validation Mean IoU: 55.03%
# Validation Dice Coefficient: 85.02%
# Mean Validation Loss: 24.17%
# Mean Validation Accuracy: 77.07%
# Mean Validation Dice Coefficient: 75.83%

# %%
from tensorflow.keras.models import load_model

# Load the model
model = load_model('final_unet_model.keras', custom_objects={'dice_coefficient': dice_coefficient})

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import tensorflow as tf

# Define the color map for classes
color_map = {
    0: (255, 255, 0),  # Background
    1: (199, 252, 0),  # Glacier
    2: (254, 0, 86),   # House_Building
    3: (0, 183, 235),  # Ice
    4: (134, 34, 255), # Land
    5: (255, 255, 0),  # Undefined
    6: (0, 255, 206),  # Vegetation
    7: (255, 128, 0),  # Water
}

def visualize_image_and_mask(image_path, predicted_mask, target_size, num_classes):
    """Visualize the original image and its predicted mask with colored classes side by side."""
    # Load the original image
    original_image = Image.open(image_path).convert("RGB")
    original_image = original_image.resize(target_size, Image.Resampling.LANCZOS)

    # Apply color to the predicted mask based on the color map
    colored_mask = np.zeros((predicted_mask.shape[0], predicted_mask.shape[1], 3), dtype=np.uint8)

    for class_idx in range(num_classes):
        # Create a binary mask for each class
        class_mask = (predicted_mask == class_idx).astype(np.uint8)
        colored_mask[class_mask == 1] = color_map[class_idx]  # Map the class index to a color from the color_map

    # Create a side-by-side plot
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(original_image)
    axes[0].set_title("Original Image")
    axes[0].axis('off')  # Hide axes

    axes[1].imshow(colored_mask)  # Display the colored mask
    axes[1].set_title("Predicted Mask")
    axes[1].axis('off')  # Hide axes

    plt.tight_layout()
    plt.show()

# Example function to get the predicted mask from the model (assuming it's a segmentation problem)
def predict_mask(model, image_path, target_size):
    """Predict the mask for a given image using the trained model."""
    # Load and preprocess image
    image = np.array(Image.open(image_path).convert("RGB"))
    image = resize_image(image, target_size)  # Resize image
    image = np.expand_dims(image, axis=0)  # Add batch dimension

    # Predict mask
    predicted_mask = model.predict(image)

    # Convert from one-hot encoding to class map
    predicted_mask = np.argmax(predicted_mask, axis=-1)  # Convert the one-hot encoded output to a single class label per pixel
    predicted_mask = np.squeeze(predicted_mask, axis=0)  # Remove batch dimension

    return predicted_mask

# Example usage
image_path = '/content/Shisper_2023_June_5.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
# Example usage
image_path = '/content/Shisper_2023_June_2.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
# Example usage
image_path = '/content/Shisper_2023_June_3.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
# Example usage
image_path = '/content/Shisper_2023_June_4.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
# Example usage
image_path = '/content/Shisper_2023_June_6.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Example usage
image_path = '/content/Passu_2019_July_1_jpg.rf.25988459bf8a6ebaa9ccd6c7240ed7ff.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step

# %%
# Example usage
image_path = '/content/Passu_2019_July_2_jpg.rf.212bdd55c48b6fdb6eeda8e743bffa13.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Example usage
image_path = '/content/Passu_2019_July_3_jpg.rf.e7e603acbce988a695e721891b407b38.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Example usage
image_path = '/content/Passu_2019_July_4_jpg.rf.892067a7a58dac8c1199edd274d6adc2.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Example usage
image_path = '/content/Passu_2019_September_1_jpg.rf.1a46e10426946d641c9053bd68b28ff8.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
# Example usage
image_path = '/content/Passu_2019_September_2_jpg.rf.2d143be9568ffe86e5b145f4602be360.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step

# %%
# Example usage
image_path = '/content/Passu_2019_September_3_jpg.rf.553f3554c5bbcfd4f9c00ae5e290a898.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Example usage
image_path = '/content/Passu_2019_September_4_jpg.rf.a9f1295d9250c0023bcc4c7463e2a443.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
# Example usage
image_path = '/content/Shisper_2021_June_2.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
# Example usage
image_path = '/content/Shisper_2021_June_3.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
# Example usage
image_path = '/content/Shisper_2021_June_4.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Example usage
image_path = '/content/Shisper_2021_June_5.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
# Example usage
image_path = '/content/Shisper_2021_June_6.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Example usage
image_path = '/content/Shisper_2023_June_1.jpg'  # Replace with your actual image path
predicted_mask = predict_mask(model, image_path, target_size=(patch_size, patch_size))

# Visualize the image and its predicted mask
visualize_image_and_mask(image_path, predicted_mask, target_size=(patch_size, patch_size), num_classes=8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
